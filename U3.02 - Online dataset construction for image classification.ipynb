# %%
import tensorflow as tf
from time import time
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import mlutils
# %matplotlib inline

# %% [markdown]
# ## Imágenes desde ficheros
#
# ref https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html

# %% [markdown]
# ### descargamos imágenes de dos queries en google

# %%
# !pip install google_images_download
# Out:
# Collecting google_images_download
#   Downloading https://files.pythonhosted.org/packages/18/ed/0319d30c48f3653802da8e6dcfefcea6370157d10d566ef6807cceb5ec4d/google_images_download-2.8.0.tar.gz
# Collecting selenium (from google_images_download)
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#     100% |████████████████████████████████| 911kB 37.5MB/s ta 0:00:01   35% |███████████▎                    | 317kB 932kB/s eta 0:00:01
# Requirement already satisfied: urllib3 in /home/user/.conda/envs/p37/lib/python3.7/site-packages (from selenium->google_images_download) (1.25.2)
# Building wheels for collected packages: google-images-download
#   Building wheel for google-images-download (setup.py) ... done
#   Stored in directory: /home/user/.cache/pip/wheels/1f/28/ad/f56e7061e1d2a9a1affe2f9c649c2570cb9198dd24ede0bbab
# Successfully built google-images-download
# Installing collected packages: selenium, google-images-download
# Successfully installed google-images-download-2.8.0 selenium-3.141.0

# %%
downloads = "/tmp/downloads"
traintest_imgs = "/tmp/imgs"

train_pct = .7

# %%
# !rm -rf $downloads
# !mkdir $downloads

# %%
cfg="""
{
    "Records": [
        {
            "keywords": "car",
            "format": "jpg",
            "limit": 50,
            "type": "photo",
            "size": "medium",
            "output_directory": "%s"
        },
        {
            "keywords": "truck",
            "format": "jpg",
            "limit": 50,
            "type": "photo",
            "size": "medium", 
            "output_directory": "%s"
        }
    ]
}
"""%(downloads, downloads)

# %%
with open(downloads+"/cfg.txt", "w") as f:
    f.write(cfg)

# %%
# !googleimagesdownload --config_file $downloads/cfg.txt
# Out:
# Item no.: 1 --> Item name = car
# Evaluating...
# Starting Download...
# Completed Image ====> 1.592f4169b74af41b008b5977-750-563.jpg
# Completed Image ====> 2.heres-why-the-mclaren-720s-worth-280000-is-a-difficult-car-to-love.jpg
# Completed Image ====> 3.mazda-vision-coupe-wins-2018-concept-car-of-the-year-4.jpg
# Completed Image ====> 4.Lam1_trans_NvBQzQNjv4BqnAdySV0BR-4fDN_-_p756cVfcy8zLGPV4EhRkjQy7tg.jpg
# Completed Image ====> 5.ssc-tuatara.jpg
# Completed Image ====> 6.911-road-3629a.jpg
# Completed Image ====> 7._100284183_hi044452539.jpg
# Completed Image ====> 8.McLaren-Senna-car-price-new-2018-890981.jpg
# Completed Image ====> 9.dfb51e2e4be24a07b71cbf021a81d6d3.jpg
# Completed Image ====> 10.performance.jpg
# Completed Image ====> 11.jaguarf-pace.jpg
# Completed Image ====> 12.j1qtl37vkiw9nzefmkmw.jpg
# Completed Image ====> 13.front-left-side-47.jpg
# URLError on an image...trying next one... Error: HTTP Error 403: Forbidden
# Completed Image ====> 14.ms_tw.jpg
# Completed Image ====> 15.rolls-royce-ghost.jpg
# Completed Image ====> 16.biomega-electric-car-concept-design-technology-vehicle_dezeen_2364_hero2-852x479.jpg
# Completed Image ====> 17.2018-monterey-2019-bugatti-divo-5-1200x630-c-ar1.91.jpg
# Completed Image ====> 18.mercedes-amg_a35_mercedes-amg-a35-sedan_2020-1553631895931.jpg
# Completed Image ====> 19.the-ferrari-laferrari-seen-in-knightsbridge-london-the-news-photo-934800332-1551812127.jpg
# Wrong image format returned. Skipping...
# Wrong image format returned. Skipping...
# Completed Image ====> 20.gallardo-0638.jpg
# Completed Image ====> 21.f04ad096-b71d-4059-a14e-988f8299007c.jpg
# Completed Image ====> 22._105917230_bugatti_bbc.jpg
# Completed Image ====> 23.TVR-1_trans_NvBQzQNjv4Bqx5egiJ9MQyAqq6uO2mksLewgQAgQu-frnJ3S4qwBXxU.jpg
# Completed Image ====> 24.AppleCarFront34_v003-780x439-780x439.jpg
# Completed Image ====> 25.2e3d585215d7f7908d9a2844fdd5cec8.jpg
# Completed Image ====> 26.2017-toyota-prius-prime-test-drive-ojai-california-sep-2016_100568170_m.jpg
# Completed Image ====> 27.501585-apple-concept-car.jpg
# Completed Image ====> 28.c052b7d8-4c03-4f71-a999-d906de9064ee.jpg
# Completed Image ====> 29.best-used-cars-1027426.jpg
# Completed Image ====> 30.apple-car-3-970x647-c-3-720x720.jpg
# Completed Image ====> 31.rain-prisk-1.jpg
# Completed Image ====> 32.group-a-kia-picanto.jpg
# Completed Image ====> 33.9356_main_f.jpg
# Completed Image ====> 34.636652589481890470-10Chevrolet-Corvette.JPG
# Completed Image ====> 35.electric_volkswagen_78.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 36.electric.jpg
# Completed Image ====> 37.59f3b183bcf93d1e008b548d-750-563.jpg
# Completed Image ====> 38.181126144412-04-gm-car-models-112618-exlarge-169.jpg
# Completed Image ====> 39.2019_kia_stinger_angularfront.jpg
# Completed Image ====> 40.microlino_fraumunster_web_001.jpg
# Completed Image ====> 41.img812810844-1551980833760.jpg
# Completed Image ====> 42.renault-concept-car-014.jpg
# Completed Image ====> 43.Showcar-3-760x380.jpg
# Completed Image ====> 44.MV5BMzMwYWZkZjctZTU5Ny00MDNiLTlkMmYtNzkyODMwMGUxYzA2XkEyXkFqcGdeQXVyNzU1NzE3NTg@._V1_CR0,45,480,270_AL_UX477_CR0,0,477,268_AL_.jpg
# Completed Image ====> 45.105340766-1532017490887v9-l0kjq.jpg
# Completed Image ====> 46.alfa-romeogiulia.jpg
# Completed Image ====> 47.SN-LAMBO-Read-Only.jpg
# Completed Image ====> 48.Aqua-640x398.jpg
# Completed Image ====> 49.methode%2Ftimes%2Fprod%2Fweb%2Fbin%2F696b3456-abbf-11e8-aa49-f23497b9293e.jpg
# Completed Image ====> 50.harrier-pv-landing-banner-mob.jpg
#
# Errors: 4
#
#
# Everything downloaded!
# Total errors: 4
# Total time taken: 71.22147035598755 Seconds
#
# Item no.: 1 --> Item name = truck
# Evaluating...
# Starting Download...
# Completed Image ====> 1.volvo-truck-autonomous_T2018_0314-1-1068x601.jpg
# Completed Image ====> 2.2606878260_W_S.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 3.20181119_truck.jpg
# Completed Image ====> 4.thor-trucks-road.jpg
# Completed Image ====> 5.960x0.jpg
# IOError on an image...trying next one... Error: The read operation timed out
# Completed Image ====> 6.163649.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 7.truck-brian-california.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 8.prima.jpg
# Completed Image ====> 9.https%3A%2F%2Fblogs-images.forbes.com%2Fsebastianblanco%2Ffiles%2F2019%2F04%2Ftoyota-hydrogen-semi-1200x679.jpg
# Completed Image ====> 10.pacLease-truck5.jpg
# Completed Image ====> 11.G-3_Resources_LLC_Truck.jpg
# Completed Image ====> 12.2019-ford-ranger%20supercab-frontside_ftrscabxl1901.jpg
# Completed Image ====> 13.300.jpg
# Wrong image format returned. Skipping...
# Wrong image format returned. Skipping...
# Completed Image ====> 14.dumper-truck-500x500.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 15.42641575-1-f.jpg
# Completed Image ====> 16.truck-highway-ribbon-fit.jpg
# Completed Image ====> 17.cleantruckspage.jpg
# Completed Image ====> 18.carroceria-camion-mon-tech-m-truck-20-019-003.jpg
# Completed Image ====> 19.mhcv-construck.jpg
# Completed Image ====> 20.usps-motiv-power-e450-delivery-truck-for-fresno-california_100691314_l.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 21.10259413ActivitySheetImage.jpg
# Wrong image format returned. Skipping...
# URLError on an image...trying next one... Error: HTTP Error 403: Forbidden
# Completed Image ====> 22.1558115353-2019-chevrolet-colorado-1558115347.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 23.20170321021854-11.jpg
# Completed Image ====> 24.cc_2019cht300002_02_640_gaz.jpg
# Completed Image ====> 25.vj8vweuvlupfzi4e8nak.jpg
# Completed Image ====> 26.1860x1050-sustainable-truck-year-2018-newsintro.jpg
# Completed Image ====> 27.Transformers-Optimus-Truck-Driving-Experience-Day-1920x1080-resize.jpg
# Completed Image ====> 28.dakota.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 29.V-CargoVan.jpg
# Completed Image ====> 30.LeisurePursuits_AmericanMonsterTruck1.JPG
# Completed Image ====> 31.10704948-3x2-700x467.jpg
# Completed Image ====> 32.4261014_1.jpg
# Completed Image ====> 33.2018_11_R1T_15-800x533.jpg
# Completed Image ====> 34.152142.jpg
# Completed Image ====> 35.6cf32312-d0f6-4631-9850-4f950040fd7a-2019_Ram_1500.JPG
# Completed Image ====> 36.ca44038c1a6a47768591ec154adf8250_684x384.jpg
# Completed Image ====> 37.renault-trucks-k-2019-image.jpg
# Completed Image ====> 38.DSC_0885.jpg
# Completed Image ====> 39.au-budget-trucks-deals-overnight-900x600.jpg
# Completed Image ====> 40.cascadia-rotated-500x300.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 41.5b0844fa1ae66243008b4751-750-563.jpg
# Completed Image ====> 42.1541468747198.jpg
# Completed Image ====> 43.file-20180723-189310-y111iu.jpg
# Completed Image ====> 44.Ford-Trucks-F-MAX-2019.jpg
# Completed Image ====> 45.346-autocaravana-renault-trucks-x-evasions-02.jpg
# Completed Image ====> 46.foison-truck-small.jpg
# Completed Image ====> 47.tesla-pickup-truck-1.jpg
# URLError on an image...trying next one... Error: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.eutruckplatooning.com'. (_ssl.c:1056)>
# Wrong image format returned. Skipping...
# Wrong image format returned. Skipping...
# Wrong image format returned. Skipping...
# Completed Image ====> 48.truck_lake_1.jpg
# Completed Image ====> 49.faszination-show-truck-header.jpg
# Completed Image ====> 50.actros-14c459-w768xh384-cutout.jpg
#
# Errors: 17
#
#
# Everything downloaded!
# Total errors: 21
# Total time taken: 180.88877058029175 Seconds

# %% [markdown]
# ### revisamos las imágenes y eliminamos las defectuosas

# %%
from skimage import io
files = !find $downloads -type f
for fname in files:
    if fname!=downloads+"/cfg.txt":
        print (".", end=" ")
        try:
            io.imread(fname)
        except:
            print ("\nremoving",fname,"as cannot be read\n")
            # !rm '$fname'
# Out:
# . . . . . . . . . . . . . . . . . . . . .
# removing /tmp/downloads/car/4.Lam1_trans_NvBQzQNjv4BqnAdySV0BR-4fDN_-_p756cVfcy8zLGPV4EhRkjQy7tg.jpg as cannot be read
#
# rm: cannot remove '$fname': No such file or directory
# . . . . . . . . . . . . . . .
# removing /tmp/downloads/car/23.TVR-1_trans_NvBQzQNjv4Bqx5egiJ9MQyAqq6uO2mksLewgQAgQu-frnJ3S4qwBXxU.jpg as cannot be read
#
# rm: cannot remove '$fname': No such file or directory
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# removing /tmp/downloads/truck/12.2019-ford-ranger%20supercab-frontside_ftrscabxl1901.jpg as cannot be read
#
# rm: cannot remove '$fname': No such file or directory
# . . .

# %% [markdown]
# ### organizamos las imágenes en train y en test

# %%
classdirs = !find $downloads -type d
classdirs = [i.split("/")[-1] for i in classdirs if i!=downloads]
print (classdirs)
# Out:
# ['car', 'truck']

# %%
# !rm -rf $traintest_imgs

# %%
for classdir in classdirs:
    print (classdir)
    print ("    splitting files ... ",)
    files = !find $downloads/$classdir -type f
    files = np.r_[files]
    n_train = int(len(files)*train_pct)
    files = np.random.permutation(files)
    files_train = files[:n_train]
    files_test  = files[n_train:]
    # !mkdir -p $traintest_imgs/train/$classdir
    # !mkdir -p $traintest_imgs/test/$classdir
    print ("copying files")
    for f in files_train:
        # !cp $f $traintest_imgs/train/$classdir
    for f in files_test:
        # !cp $f $traintest_imgs/test/$classdir
# Out:
# car
#     splitting files ...
# copying files
# truck
#     splitting files ...
# copying files

# %% [markdown]
# ### sanity check 1

# %%
for classdir in classdirs:
    print (classdir)
    files = !find  $traintest_imgs/train/$classdir -type f
    print ("      ",len(files), "train images")
    files = !find  $traintest_imgs/test/$classdir -type f
    print ("      ",len(files), "test images")
# Out:
# car
#        35 train images
#        15 test images
# truck
#        35 train images
#        15 test images

# %% [markdown]
# ### sanity check 2
#
# see [ImageGenerator](https://keras.io/preprocessing/image/)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
datagen = ImageDataGenerator(rescale=1./255, fill_mode='nearest')
batch_size = 10
img_size = 32
train_generator_fn = lambda: datagen.flow_from_directory(
        traintest_imgs+"/train",  # this is the target directory
        target_size=(img_size, img_size),  # all images will be resized to 150x150
        batch_size=batch_size,
        interpolation = "bilinear",
        class_mode='binary') 

test_generator_fn = lambda: datagen.flow_from_directory(
        traintest_imgs+"/test",  # this is the target directory
        target_size=(img_size, img_size),  # all images will be resized to 150x150
        batch_size=batch_size,
        interpolation = "bilinear",
        class_mode='binary')

# %%
for imgs,labels in train_generator_fn():
    if np.random.random()>.5:
        break
mlutils.show_labeled_image_mosaic(imgs, labels)
# Out:
# Found 70 images belonging to 2 classes.

# %% [markdown]
# ### train keras!!!

# %%
def get_conv_model_A(num_classes, img_size=32, compile=True):
    tf.reset_default_graph()
    tf.keras.backend.clear_session()
    print("using",num_classes,"classes")
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input_1")
    layers = tf.keras.layers.Conv2D(15,(10,10), activation="relu")(inputs)
    layers = tf.keras.layers.Flatten()(layers)
    layers = tf.keras.layers.Dense(64, activation=tf.nn.relu)(layers)
    layers = tf.keras.layers.Dropout(0.2)(layers)
    predictions = tf.keras.layers.Dense(num_classes, activation=tf.nn.softmax, name="output_1")(layers)
    model = tf.keras.Model(inputs = inputs, outputs=predictions)
    if compile:
        model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])
    return model

# %%
num_classes = len(classdirs)
model = get_conv_model_A(num_classes, img_size=img_size)

model.fit_generator(
        train_generator_fn(),
        steps_per_epoch=1000 // batch_size,
        epochs=3,
        validation_data=test_generator_fn(),
        validation_steps=400 // batch_size)
# Out:
# using 2 classes
# WARNING:tensorflow:From /home/user/.conda/envs/p37/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/user/.conda/envs/p37/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Found 70 images belonging to 2 classes.
# Found 30 images belonging to 2 classes.
# Epoch 1/3
# 3/3 [==============================] - 4s 1s/step - loss: 0.6926 - acc: 0.4667
# 7/7 [==============================] - 5s 739ms/step - loss: 1.0396 - acc: 0.4714 - val_loss: 0.6926 - val_acc: 0.4667
# Epoch 2/3
# 3/3 [==============================] - 1s 464ms/step - loss: 0.6925 - acc: 0.5333
# 7/7 [==============================] - 2s 314ms/step - loss: 0.6925 - acc: 0.5429 - val_loss: 0.6925 - val_acc: 0.5333
# Epoch 3/3
# 3/3 [==============================] - 1s 367ms/step - loss: 0.6911 - acc: 0.5333
# 7/7 [==============================] - 2s 247ms/step - loss: 0.6857 - acc: 0.7143 - val_loss: 0.6911 - val_acc: 0.5333

# %% [markdown]
# ### predictions

# %%
def show_preds(x, preds):
    for i  in np.random.permutation(range(len(preds)))[:4]:
        plt.figure(figsize=(5,2.5))
        plt.subplot(122)
        plt.imshow(x[i])
        plt.axis("off")
        plt.subplot(121)
        plt.bar(np.arange(2), preds[i], color="blue", alpha=.5, label="prediction")
        plt.bar(np.arange(2), np.eye(2,2)[int(y[i])], color="red", alpha=.5, label="label")
        plt.xticks(range(2), range(2), rotation="vertical");
        plt.xlim(-.5,1.5);
        plt.legend(loc='upper center', bbox_to_anchor=(0.5, +1.35),ncol=5)

# %%
for x,y in test_generator_fn():
    if np.random.random()>.7:
        break
        
preds = model.predict(x)
mlutils.show_preds(x, y, preds)
# Out:
# Found 30 images belonging to 2 classes.
